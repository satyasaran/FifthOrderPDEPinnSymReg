# %%
import skopt
from skopt import gp_minimize
from skopt.plots import plot_convergence, plot_objective
from skopt.space import Real, Categorical, Integer
from skopt.utils import use_named_args
from skopt import dump, load

# %%
pwd
# Out:
# '/home/trl102/Dir/MyDailyWork/PDE/DeepXde_PDE/FifthOrderPDE_PinnSymbolicRegression/Cos'

# %%
# Load the search_result object in the future
search_result = load('results_comb_gp4_a100_COS.pkl')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3))
from skopt.plots import plot_convergence
plot_convergence(search_result)
plt.savefig('Convergence_cos.eps',dpi=300)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3))
from skopt.plots import plot_convergence
plot_convergence(search_result)
plt.savefig('Convergence_comb.eps',dpi=300)

# %%
plot_objective(search_result, show_points=True, size=3.8)
plt.savefig('Convergence_cos_mp.eps',dpi=300)

# %%
search_result.x
# Out:
# [0.002469218272788538, 4, 25, 'sin', 0.011153893091407734]

# %%
search_result.x
# Out:
# [0.002469218272788538, 4, 25, 'sin', 0.011153893091407734]
