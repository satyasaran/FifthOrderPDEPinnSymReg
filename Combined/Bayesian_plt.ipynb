# %%
import skopt
from skopt import gp_minimize
from skopt.plots import plot_convergence, plot_objective
from skopt.space import Real, Categorical, Integer
from skopt.utils import use_named_args
from skopt import dump, load

# %%
# Load the search_result object in the future
search_result = load('results_comb_gp4_a100_exp_COS.pkl')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3))
from skopt.plots import plot_convergence
plot_convergence(search_result)
plt.savefig('Convergence_comb.eps',dpi=300)

# %%
plot_objective(search_result, show_points=True, size=3.8)
plt.savefig('Convergence_comb_mp.eps',dpi=300)

# %%
search_result.x
# Out:
# [0.07483695573628585, 1, 18, 'sigmoid', 0.0014261754674358806]
